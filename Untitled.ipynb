# %%
pip install -r requirements.txt
# Out:
# ERROR: Invalid requirement: 'run your code' (from line 3 of requirements.txt)
# Note: you may need to restart the kernel to use updated packages.

# %%
! pip install git+https://github.com/Spoorthi281997/ny11masu.git
# Out:
# ...
#   Cloning https://github.com/Spoorthi281997/ny11masu.git to /private/var/folders/t4/_6mb27j53xj75tpr2wfs0rzh0000gn/T/pip-req-build-67ru135a
#   Running command git clone -q https://github.com/Spoorthi281997/ny11masu.git /private/var/folders/t4/_6mb27j53xj75tpr2wfs0rzh0000gn/T/pip-req-build-67ru135a
# ...

# %%
from skimage import io
url = 'https://www.fau.de/files/2019/07/Kollegienhaus_Malter_3-480x284.jpg'
image = io.imread(url)
print(type(image))
# Out:
# <class 'numpy.ndarray'>

# %%
imshow(image,[])
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7FB4A00685E0>
